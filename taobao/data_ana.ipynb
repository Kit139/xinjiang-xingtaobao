# %%
import pandas as pd
df = pd.read_csv('./新疆杏淘宝销售1.csv')
df
# Out:
#                                     标题  \
# 0     吊干杏干500g杏脯非新疆杏肉干无红杏干添加天然酸甜果干蜜饯零食
# 1     新疆红杏干杏脯500g无吊干杏杏肉添加天然酸杏子休闲零食果脯蜜饯
# 2           新疆特产土耳其大黑杏干甜杏干杏脯无核杏肉500g包邮
# 3      吊干杏干不添加然天新疆特产2021年新货特树上干杏脯级新疆杏干
# 4     新疆特产杏干无添加天然土耳其大黑杏脯无核无糖杏肉果脯零食500g
# ...                                ...
# 3735            新疆四团树上杏干新货零食特产500克2袋包邮
# 3736   敦煌李广杏干320g甘肃特产皇宝杏肉葡萄干黑加仑树上吊干非新疆
# 3737    新疆杏包仁大漠马卡龙天然吊死杏干夹核桃仁甘草杏脯杏肉树上干杏
# 3738     英吉沙杏新疆特产杏肉小小的我杏干杏子肉果干果脯蜜饯零食小吃
# 3739   新疆杏干一杏两吃吊干杏干无添加自然风干树上果干小白杏干500g
#
#                                                    图片链接  \
# 0     https://g-search3.alicdn.com/img/bao/uploaded/...
# 1     https://g-search2.alicdn.com/img/bao/uploaded/...
# 2     https://g-search3.alicdn.com/img/bao/uploaded/...
# 3     https://g-search3.alicdn.com/img/bao/uploaded/...
# 4     https://g-search3.alicdn.com/img/bao/uploaded/...
# ...                                                 ...
# 3735  https://g-search3.alicdn.com/img/bao/uploaded/...
# ...

# %%
df['销量'] = df['销量'].str.replace('万\+','0000')
df['销量'] = df['销量'].str.strip('+')
df.to_csv('淘宝_新疆杏销售数据.csv',index=False)
# Out:
# C:\Users\kit\AppData\Local\Temp/ipykernel_13536/3085400169.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['销量'] = df['销量'].str.replace('万\+','0000')
